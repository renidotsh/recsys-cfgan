# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model

# %%
# Load MovieLens 100K dataset
url = 'http://files.grouplens.org/datasets/movielens/ml-100k/u.data'
data = pd.read_csv(url, sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# %%
# Parameters
latent_dim = 10
num_users = data['user_id'].nunique()  # Number of unique users
num_items = data['item_id'].nunique()  # Number of unique items
batch_size = 64
epochs = 100

# %%
# Normalize the ratings to be between 0 and 1
ratings = data['rating'].values
ratings = (ratings - ratings.min()) / (ratings.max() - ratings.min())

# Generate user and item embeddings from the data
user_embeddings = np.random.normal(size=(num_users, latent_dim))
item_embeddings = np.random.normal(size=(num_items, latent_dim))

# %%
# Create the interaction matrix (user-item interactions)
interaction_matrix = np.zeros((num_users, num_items))
for i, row in data.iterrows():
    user_idx = row['user_id'] - 1  # User ID starts at 1, so subtract 1 for indexing
    item_idx = row['item_id'] - 1  # Item ID starts at 1, so subtract 1 for indexing
    interaction_matrix[user_idx, item_idx] = ratings[i]

# %%
# Generator model
def build_generator(latent_dim, num_items):
    user_input = layers.Input(shape=(latent_dim,))
    noise_input = layers.Input(shape=(latent_dim,))
    merged = layers.Concatenate()([user_input, noise_input])
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dense(256, activation='relu')(x)
    generated_items = layers.Dense(num_items, activation='sigmoid')(x)
    return Model([user_input, noise_input], generated_items)

# %%
# Discriminator model
def build_discriminator(latent_dim, num_items):
    user_input = layers.Input(shape=(latent_dim,))
    item_input = layers.Input(shape=(num_items,))
    merged = layers.Concatenate()([user_input, item_input])
    x = layers.Dense(256, activation='relu')(merged)
    x = layers.Dense(128, activation='relu')(x)
    validity = layers.Dense(1, activation='sigmoid')(x)
    return Model([user_input, item_input], validity)

# %%
# Build models
generator = build_generator(latent_dim, num_items)
discriminator = build_discriminator(latent_dim, num_items)

# Optimizers
optimizer = tf.keras.optimizers.Adam(0.0002, 0.5)

# Compile discriminator
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Build and compile the combined model
discriminator.trainable = False
user_input = layers.Input(shape=(latent_dim,))
noise_input = layers.Input(shape=(latent_dim,))
generated_items = generator([user_input, noise_input])
validity = discriminator([user_input, generated_items])
combined = Model([user_input, noise_input], validity)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)

# %%
# Training loop
for epoch in range(epochs):
    # Select a random batch of users
    idx = np.random.randint(0, num_users, batch_size)
    users = user_embeddings[idx]

    # Generate random noise
    noise = np.random.normal(0, 1, (batch_size, latent_dim))

    # Generate a batch of fake item interactions
    fake_items = generator.predict([users, noise])

    # Get a batch of real item interactions
    real_items = interaction_matrix[idx]

    # Labels for real and fake data
    real = np.ones((batch_size, 1))
    fake = np.zeros((batch_size, 1))

    # Train discriminator
    d_loss_real = discriminator.train_on_batch([users, real_items], real)
    d_loss_fake = discriminator.train_on_batch([users, fake_items], fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)

    # Train generator
    g_loss = combined.train_on_batch([users, noise], real)

    # Print progress
    print(f"Epoch {epoch + 1}/{epochs} [D loss: {d_loss[0]} | D accuracy: {d_loss[1]}] [G loss: {g_loss}]")
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\renis\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# Epoch 1/100 [D loss: 0.7145473957061768 | D accuracy: 0.28515625] [G loss: [array(0.62289923, dtype=float32), array(0.62289923, dtype=float32), array(0.5234375, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x00000172E1C39940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x00000172E201DB20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 2/100 [D loss: 0.6572242975234985 | D accuracy: 0.439453125] [G loss: [array(0.62880003, dtype=float32), array(0.62880003, dtype=float32), array(0.51953125, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 3/100 [D loss: 0.6500600576400757 | D accuracy: 0.47864586114883423] [G loss: [array(0.6351319, dtype=float32), array(0.6351319, dtype=float32), array(0.5260417, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 4/100 [D loss: 0.651644229888916 | D accuracy: 0.4914899468421936] [G loss: [array(0.6423391, dtype=float32), array(0.6423391, dtype=float32), array(0.5253906, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 5/100 [D loss: 0.6520670652389526 | D accuracy: 0.4969618022441864] [G loss: [array(0.6457424, dtype=float32), array(0.6457424, dtype=float32), array(0.5234375, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 6/100 [D loss: 0.6547418832778931 | D accuracy: 0.5004143118858337] [G loss: [array(0.65073705, dtype=float32), array(0.65073705, dtype=float32), array(0.52213544, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 7/100 [D loss: 0.6590538620948792 | D accuracy: 0.5051081776618958] [G loss: [array(0.65613145, dtype=float32), array(0.65613145, dtype=float32), array(0.5234375, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 8/100 [D loss: 0.663972795009613 | D accuracy: 0.5070963501930237] [G loss: [array(0.66222435, dtype=float32), array(0.66222435, dtype=float32), array(0.5214844, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 9/100 [D loss: 0.6696510314941406 | D accuracy: 0.5054636597633362] [G loss: [array(0.66858715, dtype=float32), array(0.66858715, dtype=float32), array(0.5173611, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 10/100 [D loss: 0.6760019063949585 | D accuracy: 0.4982524514198303] [G loss: [array(0.67564005, dtype=float32), array(0.67564005, dtype=float32), array(0.50390625, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 11/100 [D loss: 0.6817145943641663 | D accuracy: 0.4815171957015991] [G loss: [array(0.6824755, dtype=float32), array(0.6824755, dtype=float32), array(0.4794034, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 12/100 [D loss: 0.6882144808769226 | D accuracy: 0.45949387550354004] [G loss: [array(0.6891029, dtype=float32), array(0.6891029, dtype=float32), array(0.45703125, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 13/100 [D loss: 0.6950424313545227 | D accuracy: 0.4373077154159546] [G loss: [array(0.69650215, dtype=float32), array(0.69650215, dtype=float32), array(0.4314904, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 14/100 [D loss: 0.7022815942764282 | D accuracy: 0.41063159704208374] [G loss: [array(0.70427877, dtype=float32), array(0.70427877, dtype=float32), array(0.40401787, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 15/100 [D loss: 0.7104964256286621 | D accuracy: 0.38569504022598267] [G loss: [array(0.7126942, dtype=float32), array(0.7126942, dtype=float32), array(0.3796875, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 16/100 [D loss: 0.71869957447052 | D accuracy: 0.36392703652381897] [G loss: [array(0.72181416, dtype=float32), array(0.72181416, dtype=float32), array(0.35839844, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 17/100 [D loss: 0.7277068495750427 | D accuracy: 0.34429311752319336] [G loss: [array(0.73122746, dtype=float32), array(0.73122746, dtype=float32), array(0.33915442, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 18/100 [D loss: 0.7367810606956482 | D accuracy: 0.32620906829833984] [G loss: [array(0.7405615, dtype=float32), array(0.7405615, dtype=float32), array(0.3216146, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 19/100 [D loss: 0.7463868856430054 | D accuracy: 0.31047186255455017] [G loss: [array(0.7505983, dtype=float32), array(0.7505983, dtype=float32), array(0.30633223, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 20/100 [D loss: 0.7560763359069824 | D accuracy: 0.296329140663147] [G loss: [array(0.7602823, dtype=float32), array(0.7602823, dtype=float32), array(0.29257813, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 21/100 [D loss: 0.7655278444290161 | D accuracy: 0.28430330753326416] [G loss: [array(0.76989084, dtype=float32), array(0.76989084, dtype=float32), array(0.28087798, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 22/100 [D loss: 0.7749810814857483 | D accuracy: 0.2733837962150574] [G loss: [array(0.77986413, dtype=float32), array(0.77986413, dtype=float32), array(0.27024147, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 23/100 [D loss: 0.7847335338592529 | D accuracy: 0.26308122277259827] [G loss: [array(0.78963107, dtype=float32), array(0.78963107, dtype=float32), array(0.26019022, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 24/100 [D loss: 0.795307457447052 | D accuracy: 0.2529885768890381] [G loss: [array(0.800673, dtype=float32), array(0.800673, dtype=float32), array(0.25032553, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 25/100 [D loss: 0.8060821294784546 | D accuracy: 0.24402742087841034] [G loss: [array(0.8117067, dtype=float32), array(0.8117067, dtype=float32), array(0.2415625, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 26/100 [D loss: 0.817053496837616 | D accuracy: 0.23576250672340393] [G loss: [array(0.82258505, dtype=float32), array(0.82258505, dtype=float32), array(0.23347355, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 27/100 [D loss: 0.8286474943161011 | D accuracy: 0.22928404808044434] [G loss: [array(0.83520454, dtype=float32), array(0.83520454, dtype=float32), array(0.2271412, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 28/100 [D loss: 0.8411284685134888 | D accuracy: 0.22299107909202576] [G loss: [array(0.84758645, dtype=float32), array(0.84758645, dtype=float32), array(0.22098215, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 29/100 [D loss: 0.8529880046844482 | D accuracy: 0.2165924608707428] [G loss: [array(0.85932994, dtype=float32), array(0.85932994, dtype=float32), array(0.21470906, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 30/100 [D loss: 0.8644347786903381 | D accuracy: 0.21114936470985413] [G loss: [array(0.8709145, dtype=float32), array(0.8709145, dtype=float32), array(0.209375, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 31/100 [D loss: 0.8764703273773193 | D accuracy: 0.20555220544338226] [G loss: [array(0.8832721, dtype=float32), array(0.8832721, dtype=float32), array(0.20388106, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 32/100 [D loss: 0.8889425992965698 | D accuracy: 0.1995694637298584] [G loss: [array(0.8959759, dtype=float32), array(0.8959759, dtype=float32), array(0.19799805, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 33/100 [D loss: 0.9012486934661865 | D accuracy: 0.19466783106327057] [G loss: [array(0.90811247, dtype=float32), array(0.90811247, dtype=float32), array(0.19318181, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 34/100 [D loss: 0.9141836166381836 | D accuracy: 0.18889924883842468] [G loss: [array(0.9213677, dtype=float32), array(0.9213677, dtype=float32), array(0.1875, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 35/100 [D loss: 0.9265760183334351 | D accuracy: 0.18436205387115479] [G loss: [array(0.9335359, dtype=float32), array(0.9335359, dtype=float32), array(0.18303572, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 36/100 [D loss: 0.9386603832244873 | D accuracy: 0.18029728531837463] [G loss: [array(0.94556725, dtype=float32), array(0.94556725, dtype=float32), array(0.17903645, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 37/100 [D loss: 0.9508928060531616 | D accuracy: 0.17624114453792572] [G loss: [array(0.9579835, dtype=float32), array(0.9579835, dtype=float32), array(0.17504223, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 38/100 [D loss: 0.9630335569381714 | D accuracy: 0.1721929907798767] [G loss: [array(0.97023946, dtype=float32), array(0.97023946, dtype=float32), array(0.17105263, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 39/100 [D loss: 0.9752084016799927 | D accuracy: 0.1693618893623352] [G loss: [array(0.9825012, dtype=float32), array(0.9825012, dtype=float32), array(0.16826923, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 40/100 [D loss: 0.988136887550354 | D accuracy: 0.16529741883277893] [G loss: [array(0.9959606, dtype=float32), array(0.9959606, dtype=float32), array(0.16425781, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 41/100 [D loss: 1.0014424324035645 | D accuracy: 0.16181591153144836] [G loss: [array(1.0093002, dtype=float32), array(1.0093002, dtype=float32), array(0.16082317, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 42/100 [D loss: 1.0148283243179321 | D accuracy: 0.15812692046165466] [G loss: [array(1.0227587, dtype=float32), array(1.0227587, dtype=float32), array(0.15718006, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 43/100 [D loss: 1.0280678272247314 | D accuracy: 0.15534156560897827] [G loss: [array(1.0358483, dtype=float32), array(1.0358483, dtype=float32), array(0.15443315, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 44/100 [D loss: 1.0412400960922241 | D accuracy: 0.15250498056411743] [G loss: [array(1.0492772, dtype=float32), array(1.0492772, dtype=float32), array(0.15163352, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 45/100 [D loss: 1.0540311336517334 | D accuracy: 0.1503189355134964] [G loss: [array(1.0616585, dtype=float32), array(1.0616585, dtype=float32), array(0.14947917, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 46/100 [D loss: 1.0661499500274658 | D accuracy: 0.14771616458892822] [G loss: [array(1.073647, dtype=float32), array(1.073647, dtype=float32), array(0.14690897, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 47/100 [D loss: 1.0787060260772705 | D accuracy: 0.14555898308753967] [G loss: [array(1.0865929, dtype=float32), array(1.0865929, dtype=float32), array(0.14478059, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 48/100 [D loss: 1.0916016101837158 | D accuracy: 0.14300130307674408] [G loss: [array(1.0995756, dtype=float32), array(1.0995756, dtype=float32), array(0.14225261, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 49/100 [D loss: 1.1045966148376465 | D accuracy: 0.14038830995559692] [G loss: [array(1.1124709, dtype=float32), array(1.1124709, dtype=float32), array(0.13966836, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 50/100 [D loss: 1.1174790859222412 | D accuracy: 0.13772332668304443] [G loss: [array(1.1255385, dtype=float32), array(1.1255385, dtype=float32), array(0.13703126, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 51/100 [D loss: 1.1295667886734009 | D accuracy: 0.1356252133846283] [G loss: [array(1.136666, dtype=float32), array(1.136666, dtype=float32), array(0.1349571, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Epoch 52/100 [D loss: 1.1413145065307617 | D accuracy: 0.13375917077064514] [G loss: [array(1.1492562, dtype=float32), array(1.1492562, dtype=float32), array(0.13311298, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 53/100 [D loss: 1.1538302898406982 | D accuracy: 0.13196386396884918] [G loss: [array(1.1616681, dtype=float32), array(1.1616681, dtype=float32), array(0.13133845, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 54/100 [D loss: 1.1660749912261963 | D accuracy: 0.12994466722011566] [G loss: [array(1.1737498, dtype=float32), array(1.1737498, dtype=float32), array(0.12934028, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 55/100 [D loss: 1.1785705089569092 | D accuracy: 0.12814193964004517] [G loss: [array(1.1868627, dtype=float32), array(1.1868627, dtype=float32), array(0.12755682, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 56/100 [D loss: 1.1913371086120605 | D accuracy: 0.1265440285205841] [G loss: [array(1.1993195, dtype=float32), array(1.1993195, dtype=float32), array(0.12597656, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 57/100 [D loss: 1.2035143375396729 | D accuracy: 0.12458942085504532] [G loss: [array(1.2113163, dtype=float32), array(1.2113163, dtype=float32), array(0.12404057, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 58/100 [D loss: 1.2153277397155762 | D accuracy: 0.1233789324760437] [G loss: [array(1.2227559, dtype=float32), array(1.2227559, dtype=float32), array(0.12284483, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 59/100 [D loss: 1.227344036102295 | D accuracy: 0.12194369733333588] [G loss: [array(1.2353708, dtype=float32), array(1.2353708, dtype=float32), array(0.12142479, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 60/100 [D loss: 1.2393701076507568 | D accuracy: 0.120425745844841] [G loss: [array(1.2468972, dtype=float32), array(1.2468972, dtype=float32), array(0.11992188, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 61/100 [D loss: 1.2510836124420166 | D accuracy: 0.11882917582988739] [G loss: [array(1.2589079, dtype=float32), array(1.2589079, dtype=float32), array(0.11834016, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 62/100 [D loss: 1.26278555393219 | D accuracy: 0.11690475046634674] [G loss: [array(1.2702004, dtype=float32), array(1.2702004, dtype=float32), array(0.11643145, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 63/100 [D loss: 1.2740967273712158 | D accuracy: 0.11578869074583054] [G loss: [array(1.2818601, dtype=float32), array(1.2818601, dtype=float32), array(0.11532738, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 64/100 [D loss: 1.2857391834259033 | D accuracy: 0.11433999240398407] [G loss: [array(1.2931938, dtype=float32), array(1.2931938, dtype=float32), array(0.1138916, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 65/100 [D loss: 1.2974296808242798 | D accuracy: 0.11293604969978333] [G loss: [array(1.3054621, dtype=float32), array(1.3054621, dtype=float32), array(0.1125, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 66/100 [D loss: 1.3092355728149414 | D accuracy: 0.11181245744228363] [G loss: [array(1.3167244, dtype=float32), array(1.3167244, dtype=float32), array(0.11138731, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 67/100 [D loss: 1.3204596042633057 | D accuracy: 0.11048844456672668] [G loss: [array(1.3279558, dtype=float32), array(1.3279558, dtype=float32), array(0.11007462, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 68/100 [D loss: 1.3315770626068115 | D accuracy: 0.10908819735050201] [G loss: [array(1.3390411, dtype=float32), array(1.3390411, dtype=float32), array(0.10868566, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 69/100 [D loss: 1.3423725366592407 | D accuracy: 0.1078423336148262] [G loss: [array(1.3497168, dtype=float32), array(1.3497168, dtype=float32), array(0.10745018, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 70/100 [D loss: 1.3531990051269531 | D accuracy: 0.1067441999912262] [G loss: [array(1.360655, dtype=float32), array(1.360655, dtype=float32), array(0.10636161, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 71/100 [D loss: 1.3642549514770508 | D accuracy: 0.10589796304702759] [G loss: [array(1.3718053, dtype=float32), array(1.3718053, dtype=float32), array(0.10552377, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 72/100 [D loss: 1.3753982782363892 | D accuracy: 0.10474865138530731] [G loss: [array(1.3829979, dtype=float32), array(1.3829979, dtype=float32), array(0.10438368, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 73/100 [D loss: 1.3858661651611328 | D accuracy: 0.10363094508647919] [G loss: [array(1.3927666, dtype=float32), array(1.3927666, dtype=float32), array(0.10327483, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 74/100 [D loss: 1.3960702419281006 | D accuracy: 0.10275541990995407] [G loss: [array(1.4033192, dtype=float32), array(1.4033192, dtype=float32), array(0.1024071, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 75/100 [D loss: 1.406564474105835 | D accuracy: 0.10158976912498474] [G loss: [array(1.4137702, dtype=float32), array(1.4137702, dtype=float32), array(0.10125, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 76/100 [D loss: 1.4169461727142334 | D accuracy: 0.10055802762508392] [G loss: [array(1.424305, dtype=float32), array(1.424305, dtype=float32), array(0.10022615, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 77/100 [D loss: 1.4274699687957764 | D accuracy: 0.09965496510267258] [G loss: [array(1.4346946, dtype=float32), array(1.4346946, dtype=float32), array(0.09933036, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 78/100 [D loss: 1.4375898838043213 | D accuracy: 0.09907658398151398] [G loss: [array(1.4446088, dtype=float32), array(1.4446088, dtype=float32), array(0.09875801, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 79/100 [D loss: 1.4475529193878174 | D accuracy: 0.09841369092464447] [G loss: [array(1.4546412, dtype=float32), array(1.4546412, dtype=float32), array(0.09810127, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 80/100 [D loss: 1.4577546119689941 | D accuracy: 0.09786538779735565] [G loss: [array(1.4650697, dtype=float32), array(1.4650697, dtype=float32), array(0.0975586, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 81/100 [D loss: 1.4681681394577026 | D accuracy: 0.09742739796638489] [G loss: [array(1.475467, dtype=float32), array(1.475467, dtype=float32), array(0.09712577, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 82/100 [D loss: 1.4784650802612305 | D accuracy: 0.09661787748336792] [G loss: [array(1.4855379, dtype=float32), array(1.4855379, dtype=float32), array(0.09632241, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 83/100 [D loss: 1.4883205890655518 | D accuracy: 0.09563909471035004] [G loss: [array(1.4952297, dtype=float32), array(1.4952297, dtype=float32), array(0.09535015, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 84/100 [D loss: 1.4985164403915405 | D accuracy: 0.09487024694681168] [G loss: [array(1.505982, dtype=float32), array(1.505982, dtype=float32), array(0.09458705, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 85/100 [D loss: 1.5089411735534668 | D accuracy: 0.09411954879760742] [G loss: [array(1.5161208, dtype=float32), array(1.5161208, dtype=float32), array(0.09384191, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 86/100 [D loss: 1.5188143253326416 | D accuracy: 0.09384191036224365] [G loss: [array(1.5258385, dtype=float32), array(1.5258385, dtype=float32), array(0.09356832, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 87/100 [D loss: 1.5288376808166504 | D accuracy: 0.09339054673910141] [G loss: [array(1.5360621, dtype=float32), array(1.5360621, dtype=float32), array(0.09312141, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 88/100 [D loss: 1.5388069152832031 | D accuracy: 0.09250430762767792] [G loss: [array(1.5457517, dtype=float32), array(1.5457517, dtype=float32), array(0.09224077, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 89/100 [D loss: 1.548133373260498 | D accuracy: 0.09225425124168396] [G loss: [array(1.5547677, dtype=float32), array(1.5547677, dtype=float32), array(0.09199438, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 90/100 [D loss: 1.5574660301208496 | D accuracy: 0.09148748219013214] [G loss: [array(1.5643358, dtype=float32), array(1.5643358, dtype=float32), array(0.09123264, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 91/100 [D loss: 1.5669586658477783 | D accuracy: 0.09099587053060532] [G loss: [array(1.5738428, dtype=float32), array(1.5738428, dtype=float32), array(0.0907452, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 92/100 [D loss: 1.5766985416412354 | D accuracy: 0.09042982757091522] [G loss: [array(1.5837656, dtype=float32), array(1.5837656, dtype=float32), array(0.09018342, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 93/100 [D loss: 1.586596965789795 | D accuracy: 0.08996021747589111] [G loss: [array(1.5936681, dtype=float32), array(1.5936681, dtype=float32), array(0.08971774, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 94/100 [D loss: 1.5962748527526855 | D accuracy: 0.08916729688644409] [G loss: [array(1.6030358, dtype=float32), array(1.6030358, dtype=float32), array(0.08892952, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 95/100 [D loss: 1.6057555675506592 | D accuracy: 0.08847357332706451] [G loss: [array(1.6127098, dtype=float32), array(1.6127098, dtype=float32), array(0.08824013, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 96/100 [D loss: 1.615265130996704 | D accuracy: 0.08787592500448227] [G loss: [array(1.6220021, dtype=float32), array(1.6220021, dtype=float32), array(0.08764648, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 97/100 [D loss: 1.624502420425415 | D accuracy: 0.0875328853726387] [G loss: [array(1.6312944, dtype=float32), array(1.6312944, dtype=float32), array(0.0873067, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 98/100 [D loss: 1.6337659358978271 | D accuracy: 0.08679723739624023] [G loss: [array(1.6404492, dtype=float32), array(1.6404492, dtype=float32), array(0.08657525, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 99/100 [D loss: 1.6425869464874268 | D accuracy: 0.08631384372711182] [G loss: [array(1.6489862, dtype=float32), array(1.6489862, dtype=float32), array(0.08609533, dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 100/100 [D loss: 1.6512837409973145 | D accuracy: 0.08568349480628967] [G loss: [array(1.6577526, dtype=float32), array(1.6577526, dtype=float32), array(0.08546875, dtype=float32)]]
