# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import layers, Model

# Load MovieLens 100K dataset
url = 'http://files.grouplens.org/datasets/movielens/ml-100k/u.data'
data = pd.read_csv(url, sep='\t', names=['user_id', 'item_id', 'rating', 'timestamp'])

# Parameters
latent_dim = 20
num_users = data['user_id'].nunique()  # Number of unique users
num_items = data['item_id'].nunique()  # Number of unique items
batch_size = 64
epochs = 50

# Normalize the ratings to be between 0 and 1
ratings = data['rating'].values
ratings = (ratings - ratings.min()) / (ratings.max() - ratings.min())

# Create trainable embeddings for users and items
user_embedding_layer = layers.Embedding(input_dim=num_users, output_dim=latent_dim, input_length=1)
item_embedding_layer = layers.Embedding(input_dim=num_items, output_dim=latent_dim, input_length=1)

# Create the interaction matrix (user-item interactions)
interaction_matrix = np.zeros((num_users, num_items))
for i, row in data.iterrows():
    user_idx = row['user_id'] - 1  # User ID starts at 1, so subtract 1 for indexing
    item_idx = row['item_id'] - 1  # Item ID starts at 1, so subtract 1 for indexing
    interaction_matrix[user_idx, item_idx] = ratings[i]

# Generator model
def build_generator(latent_dim, num_items):
    user_id_input = layers.Input(shape=(1,))  # User ID as input
    user_embedding = user_embedding_layer(user_id_input)  # Lookup embedding
    user_embedding = layers.Flatten()(user_embedding)
    
    noise_input = layers.Input(shape=(latent_dim,))  # Random noise
    merged = layers.Concatenate()([user_embedding, noise_input])
    
    x = layers.Dense(128, activation='relu')(merged)
    x = layers.Dense(256, activation='relu')(x)
    generated_items = layers.Dense(num_items, activation='sigmoid')(x)
    
    return Model([user_id_input, noise_input], generated_items)

# Discriminator model
def build_discriminator(latent_dim, num_items):
    user_id_input = layers.Input(shape=(1,))  # User ID as input
    user_embedding = user_embedding_layer(user_id_input)  # Lookup embedding
    user_embedding = layers.Flatten()(user_embedding)
    
    item_input = layers.Input(shape=(num_items,))  # Item interaction matrix
    merged = layers.Concatenate()([user_embedding, item_input])
    
    x = layers.Dense(256, activation='relu')(merged)
    x = layers.Dense(128, activation='relu')(x)
    validity = layers.Dense(1, activation='sigmoid')(x)
    
    return Model([user_id_input, item_input], validity)

# Build models
generator = build_generator(latent_dim, num_items)
discriminator = build_discriminator(latent_dim, num_items)

# Optimizers
optimizer = tf.keras.optimizers.Adam(0.0002, 0.5)

# Compile discriminator
discriminator.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# Build and compile the combined model
discriminator.trainable = False
user_input = layers.Input(shape=(1,))
noise_input = layers.Input(shape=(latent_dim,))
generated_items = generator([user_input, noise_input])
validity = discriminator([user_input, generated_items])
combined = Model([user_input, noise_input], validity)
combined.compile(loss='binary_crossentropy', optimizer=optimizer)

# Training loop
for epoch in range(epochs):
    # Select a random batch of user IDs
    user_ids = np.random.randint(0, num_users, batch_size)
    
    # Generate random noise
    noise = np.random.normal(0, 1, (batch_size, latent_dim))
    
    # Generate fake item interactions
    fake_items = generator.predict([user_ids, noise])
    
    # Get real item interactions from interaction matrix
    real_items = interaction_matrix[user_ids]
    
    # Labels for real and fake data
    real = np.ones((batch_size, 1)) * 0.9  # Smoothed labels
    fake = np.zeros((batch_size, 1)) + 0.1
    
    # Train discriminator
    d_loss_real = discriminator.train_on_batch([user_ids, real_items], real)
    d_loss_fake = discriminator.train_on_batch([user_ids, fake_items], fake)
    d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
    
    # Train generator
    g_loss = combined.train_on_batch([user_ids, noise], real)
    
    # Print progress
    print(f"Epoch {epoch + 1}/{epochs} [D loss: {d_loss[0]} | D accuracy: {d_loss[1]}] [G loss: {g_loss}]")
# Out:
# C:\Users\renis\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# C:\Users\renis\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\trainer.py:75: UserWarning: The model does not have any trainable weights.
#   warnings.warn("The model does not have any trainable weights.")
# Epoch 1/50 [D loss: 0.7834852933883667 | D accuracy: 0.0] [G loss: [array(0.97387266, dtype=float32), array(0.97387266, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x0000029617B51B20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_train_function.<locals>.one_step_on_iterator at 0x0000029617E39B20> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Epoch 2/50 [D loss: 0.9154446125030518 | D accuracy: 0.0] [G loss: [array(0.98364806, dtype=float32), array(0.98364806, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 3/50 [D loss: 0.9486445188522339 | D accuracy: 0.0] [G loss: [array(0.99291867, dtype=float32), array(0.99291867, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 20/50 [D loss: 1.1480705738067627 | D accuracy: 0.0] [G loss: [array(1.1588192, dtype=float32), array(1.1588192, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 21/50 [D loss: 1.1552355289459229 | D accuracy: 0.0] [G loss: [array(1.1656545, dtype=float32), array(1.1656545, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 22/50 [D loss: 1.162416934967041 | D accuracy: 0.0] [G loss: [array(1.1723943, dtype=float32), array(1.1723943, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 23/50 [D loss: 1.1693289279937744 | D accuracy: 0.0] [G loss: [array(1.179123, dtype=float32), array(1.179123, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Epoch 24/50 [D loss: 1.17576003074646 | D accuracy: 0.0] [G loss: [array(1.1850009, dtype=float32), array(1.1850009, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Epoch 25/50 [D loss: 1.181150197982788 | D accuracy: 0.0] [G loss: [array(1.1898372, dtype=float32), array(1.1898372, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 26/50 [D loss: 1.1864633560180664 | D accuracy: 0.0] [G loss: [array(1.1949592, dtype=float32), array(1.1949592, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 27/50 [D loss: 1.1916093826293945 | D accuracy: 0.0] [G loss: [array(1.1998032, dtype=float32), array(1.1998032, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Epoch 28/50 [D loss: 1.1964396238327026 | D accuracy: 0.0] [G loss: [array(1.2040999, dtype=float32), array(1.2040999, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 29/50 [D loss: 1.2010259628295898 | D accuracy: 0.0] [G loss: [array(1.2084528, dtype=float32), array(1.2084528, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 30/50 [D loss: 1.2050104141235352 | D accuracy: 0.0] [G loss: [array(1.2120497, dtype=float32), array(1.2120497, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 31/50 [D loss: 1.2087984085083008 | D accuracy: 0.0] [G loss: [array(1.2156615, dtype=float32), array(1.2156615, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 32/50 [D loss: 1.2128740549087524 | D accuracy: 0.0] [G loss: [array(1.219844, dtype=float32), array(1.219844, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 33/50 [D loss: 1.2169780731201172 | D accuracy: 0.0] [G loss: [array(1.2237245, dtype=float32), array(1.2237245, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 34/50 [D loss: 1.2204887866973877 | D accuracy: 0.0] [G loss: [array(1.2268124, dtype=float32), array(1.2268124, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 35/50 [D loss: 1.2238067388534546 | D accuracy: 0.0] [G loss: [array(1.2300227, dtype=float32), array(1.2300227, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 36/50 [D loss: 1.2271345853805542 | D accuracy: 0.0] [G loss: [array(1.2331718, dtype=float32), array(1.2331718, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 37/50 [D loss: 1.2301652431488037 | D accuracy: 0.0] [G loss: [array(1.2359302, dtype=float32), array(1.2359302, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 38/50 [D loss: 1.2327773571014404 | D accuracy: 0.0] [G loss: [array(1.2382947, dtype=float32), array(1.2382947, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 39/50 [D loss: 1.2351820468902588 | D accuracy: 0.0] [G loss: [array(1.2404643, dtype=float32), array(1.2404643, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 40/50 [D loss: 1.237442970275879 | D accuracy: 0.0] [G loss: [array(1.2426518, dtype=float32), array(1.2426518, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 41/50 [D loss: 1.239641547203064 | D accuracy: 0.0] [G loss: [array(1.2446637, dtype=float32), array(1.2446637, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 42/50 [D loss: 1.2419008016586304 | D accuracy: 0.0] [G loss: [array(1.2469689, dtype=float32), array(1.2469689, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 43/50 [D loss: 1.2442519664764404 | D accuracy: 0.0] [G loss: [array(1.2490392, dtype=float32), array(1.2490392, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Epoch 44/50 [D loss: 1.2461342811584473 | D accuracy: 0.0] [G loss: [array(1.2508887, dtype=float32), array(1.2508887, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 45/50 [D loss: 1.2481881380081177 | D accuracy: 0.0] [G loss: [array(1.2528788, dtype=float32), array(1.2528788, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 46/50 [D loss: 1.2498903274536133 | D accuracy: 0.0] [G loss: [array(1.2542393, dtype=float32), array(1.2542393, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 47/50 [D loss: 1.2514599561691284 | D accuracy: 0.0] [G loss: [array(1.2558211, dtype=float32), array(1.2558211, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 48/50 [D loss: 1.2531776428222656 | D accuracy: 0.0] [G loss: [array(1.2574496, dtype=float32), array(1.2574496, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Epoch 49/50 [D loss: 1.2547986507415771 | D accuracy: 0.0] [G loss: [array(1.2590069, dtype=float32), array(1.2590069, dtype=float32), array(0., dtype=float32)]]
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Epoch 50/50 [D loss: 1.2561719417572021 | D accuracy: 0.0] [G loss: [array(1.2602134, dtype=float32), array(1.2602134, dtype=float32), array(0., dtype=float32)]]
